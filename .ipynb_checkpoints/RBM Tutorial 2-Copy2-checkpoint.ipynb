# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
class RBM(object):
    def __init__(self, vis_unit, hidd_unit,temps=np.array(1)):
        self.vis_unit = vis_unit
        self.hidd_unit = hidd_unit
        self.temps=temps 
        #Initialise the parameters
        self.W = np.random.rand(self.vis_unit, self.hidd_unit)
        #MCMC chains
        self.chain_vis=np.random.binomial(1,0.5,vis_unit).reshape(vis_unit,1)
        self.p_v=self.chain_vis
        
        self.chain_hid=np.random.binomial(1,0.5,hidd_unit).reshape(hidd_unit,1)
        self.p_h=self.chain_hid
        self.n_samples=0
################################################ Updating Parameters ##########################################        
    
    def rbm_update_ps(self): #one sample at a time, MCMC by backward and forward pass
        hid=self.forward_pass(self.chain_vis)
        self.chain_hid=hid
        vis=self.backward_pass(hid)
        self.chain_vis=vis
        self.p_v_chain=(self.p_v*(self.n_samples)+self.chain_vis)/(self.n_samples+1)
        self.p_h_chain=(self.p_h*(self.n_samples)+self.chain_hid)/(self.n_samples+1)
        self.n_samples+=1
            
    
    #Derivative of the log probability
    def VH(self, vis,hid):
        shvd= np.tensordot(vis,hid.T,axes=1)
        return shvd
        
   
    # Upgrade the gradient     
    def W_Update(self, vis):
        #Positive phase
        hid=self.forward_pass(vis)
        der_W1 =self.VH(vis,hid) 
            
        #Negative phase
        vis_r = self.reconstruction(self.CD_k, vis)
        hid_r= self.forward_pass(vis_r)
        der_W2 = self.VH(vis_r,hid_r) 
        der_W=-der_W2+der_W1
        #der_W=der_W/np.sqrt(np.sum(der_W**2)/(self.hidd_unit*self.vis_unit))
        
        #Updatinf the parameters
        self.W = self.W + self.learning_rate*der_W/vis.shape[1]
        
    def W_Update_Chain(self,vis):
        hid=self.forward_pass(vis)
        der_W1 =self.VH(vis,hid)/vis.shape[1]
        
        #model
        self.rbm_update_ps()
        der_W2=self.VH((2*self.p_v_chain-1),(2*self.p_h_chain-1))
        der_W=-der_W2+der_W1
        #der_W=der_W/np.sqrt(np.sum(der_W**2)/(self.hidd_unit*self.vis_unit))
        
        #Updatinf the parameters
        self.W = self.W + self.learning_rate*der_W
    
    def W_Update2(self, vis):
        #Positive phase
        X = np.tensordot(self.W.T, vis, axes=1)
        p_h = 1.0/(1.0+np.exp(-2*X))
        der_W1 =self.VH(vis,2*p_h-1) 
            
        #Negative phase
        vis_r = self.reconstruction(self.CD_k, vis)
        X = np.tensordot(self.W.T, vis_r, axes=1)
        p_h = 1.0/(1.0+np.exp(-2*X))
        der_W2 = self.VH(vis_r,2*p_h-1) 
        der_W=-der_W2+der_W1
        #der_W=der_W/np.sqrt(np.sum(der_W**2)/(self.hidd_unit*self.vis_unit))
        
        #Updatinf the parameters
        self.W = self.W + self.learning_rate*der_W/vis.shape[1]
        
########################################### Reconstruction ####################################################       
        
     #Calculate the hidden states 
    def forward_pass(self, vis):
        X = np.tensordot(self.W.T, vis, axes=1)
        p_h = 1.0/(1.0+np.exp(-2*X))
        hid  = 2*(p_h>np.random.rand(self.hidd_unit, vis.shape[1]))-1
        return hid            
            
    # Reconstruct the visible states   
    def backward_pass(self, hid):
        X = np.tensordot(self.W,hid,axes=1)
        p_v = 1.0/(1.0+np.exp(-2*X))
        v_r = 2*(p_v>np.random.rand(self.vis_unit,hid.shape[1]))-1
        return v_r
            
    # Perform Gibbs Sampling
    def reconstruction(self, steps, vis):
        vis_r=vis
        for i in np.arange(steps):
            hid = self.forward_pass(vis_r)
            vis_r = self.backward_pass(hid)
        return vis_r
    
############################################# Training ########################################################

    #Training Model    
    def learn(self, training_data, learning_rate=0.01, epochs=10, batch_size=1, CD_k=1):
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.batch_size = batch_size
        self.CD_k = CD_k
        
        num_batches = int(training_data.shape[0]/self.batch_size)
        self.error_history=np.zeros(self.epochs)
        
        for k in np.arange(self.epochs):
            error = 0
            for b in np.arange(0, num_batches):
                batch = training_data[int(b*self.batch_size):int((b+1)*self.batch_size)]
                vis=batch.T
                self.W_Update(vis)
                samples = self.reconstruction(1, vis)
                error += 0.25*np.sum((vis - samples)**2)/np.prod(vis.shape)
            error=error/num_batches
            self.error_history[k]=error
            print('Epoch:%d,Training error:%f'%(k, error))

# %%
training_data = np.loadtxt('filename.txt')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-b056c7296fe7> in <module>
# ----> 1 training_data = np.loadtxt('filename.txt')
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     966             fname = os_fspath(fname)
#     967         if _is_string_like(fname):
# --> 968             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     969             fencoding = getattr(fh, 'encoding', 'latin1')
#     970             fh = iter(fh)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     267
#     268     ds = DataSource(destpath)
# --> 269     return ds.open(path, mode, encoding=encoding, newline=newline)
#     270
#     271
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     621                                       encoding=encoding, newline=newline)
#     622         else:
# --> 623             raise IOError("%s not found." % path)
#     624
#     625
#
# OSError: filename.txt not found.

# %%
training_data.shape
# Out:
# (1000000,)

# %%
data = training_data.reshape(10000,100)

# %%
new_data = data[1000:,:]

# %%
new_data.shape
# Out:
# (9000, 100)

# %%
new_data_train = new_data[:8000]

# %%
new_data_train.shape
# Out:
# (8000, 100)

# %%
new_data_test = new_data[8000:]

# %%
new_data_test.shape
# Out:
# (1000, 100)

# %%
rbm = RBM(vis_unit = 100, hidd_unit=30)

model = rbm.learn(training_data=new_data_train, learning_rate=0.01,epochs=1000, CD_k=2, batch_size=50)
# Out:
# Epoch:0,Training error:0.304695
# Epoch:1,Training error:0.217146
# Epoch:2,Training error:0.196955
# Epoch:3,Training error:0.187572
# Epoch:4,Training error:0.182430
# Epoch:5,Training error:0.178076
# Epoch:6,Training error:0.175262
# Epoch:7,Training error:0.172841
# Epoch:8,Training error:0.170082
# Epoch:9,Training error:0.168646
# Epoch:10,Training error:0.166916
# Epoch:11,Training error:0.166231
# Epoch:12,Training error:0.164710
# Epoch:13,Training error:0.163914
# Epoch:14,Training error:0.162892
# Epoch:15,Training error:0.162167
# Epoch:16,Training error:0.160984
# Epoch:17,Training error:0.160280
# Epoch:18,Training error:0.159706
# Epoch:19,Training error:0.158454
# Epoch:20,Training error:0.158091
# Epoch:21,Training error:0.157694
# Epoch:22,Training error:0.156823
# Epoch:23,Training error:0.156485
# Epoch:24,Training error:0.155974
# Epoch:25,Training error:0.156000
# Epoch:26,Training error:0.155224
# Epoch:27,Training error:0.155050
# Epoch:28,Training error:0.153670
# Epoch:29,Training error:0.153919
# Epoch:30,Training error:0.153665
# Epoch:31,Training error:0.153341
# Epoch:32,Training error:0.152952
# Epoch:33,Training error:0.152901
# Epoch:34,Training error:0.152810
# Epoch:35,Training error:0.152494
# Epoch:36,Training error:0.152694
# Epoch:37,Training error:0.151344
# Epoch:38,Training error:0.151544
# Epoch:39,Training error:0.151935
# Epoch:40,Training error:0.151806
# Epoch:41,Training error:0.151126
# Epoch:42,Training error:0.151006
# Epoch:43,Training error:0.151066
# Epoch:44,Training error:0.150571
# Epoch:45,Training error:0.150336
# Epoch:46,Training error:0.150591
# Epoch:47,Training error:0.150745
# Epoch:48,Training error:0.150244
# Epoch:49,Training error:0.150325
# Epoch:50,Training error:0.149135
# Epoch:51,Training error:0.149764
# Epoch:52,Training error:0.149276
# Epoch:53,Training error:0.149940
# Epoch:54,Training error:0.149946
# Epoch:55,Training error:0.148771
# Epoch:56,Training error:0.148830
# Epoch:57,Training error:0.149375
# Epoch:58,Training error:0.149220
# Epoch:59,Training error:0.148949
# Epoch:60,Training error:0.148240
# Epoch:61,Training error:0.148724
# Epoch:62,Training error:0.148261
# Epoch:63,Training error:0.149574
# Epoch:64,Training error:0.147940
# Epoch:65,Training error:0.148673
# Epoch:66,Training error:0.148006
# Epoch:67,Training error:0.147931
# Epoch:68,Training error:0.148684
# Epoch:69,Training error:0.148421
# Epoch:70,Training error:0.147508
# Epoch:71,Training error:0.147816
# Epoch:72,Training error:0.147931
# Epoch:73,Training error:0.147553
# Epoch:74,Training error:0.147707
# Epoch:75,Training error:0.147586
# Epoch:76,Training error:0.148105
# Epoch:77,Training error:0.147315
# Epoch:78,Training error:0.147041
# Epoch:79,Training error:0.146963
# Epoch:80,Training error:0.147481
# Epoch:81,Training error:0.146877
# Epoch:82,Training error:0.147197
# Epoch:83,Training error:0.147496
# Epoch:84,Training error:0.146745
# Epoch:85,Training error:0.146794
# Epoch:86,Training error:0.146223
# Epoch:87,Training error:0.146427
# Epoch:88,Training error:0.146514
# Epoch:89,Training error:0.146694
# Epoch:90,Training error:0.146626
# Epoch:91,Training error:0.146269
# Epoch:92,Training error:0.146564
# Epoch:93,Training error:0.146932
# Epoch:94,Training error:0.146552
# Epoch:95,Training error:0.146050
# Epoch:96,Training error:0.145944
# Epoch:97,Training error:0.146152
# Epoch:98,Training error:0.146012
# Epoch:99,Training error:0.145770
# Epoch:100,Training error:0.145986
# Epoch:101,Training error:0.145022
# Epoch:102,Training error:0.146170
# Epoch:103,Training error:0.145960
# Epoch:104,Training error:0.146037
# Epoch:105,Training error:0.145209
# Epoch:106,Training error:0.145546
# Epoch:107,Training error:0.145586
# Epoch:108,Training error:0.145535
# Epoch:109,Training error:0.146077
# Epoch:110,Training error:0.145417
# Epoch:111,Training error:0.145510
# Epoch:112,Training error:0.145313
# Epoch:113,Training error:0.145076
# Epoch:114,Training error:0.145324
# Epoch:115,Training error:0.145549
# Epoch:116,Training error:0.145211
# Epoch:117,Training error:0.145016
# Epoch:118,Training error:0.145155
# Epoch:119,Training error:0.145016
# Epoch:120,Training error:0.144634
# Epoch:121,Training error:0.144838
# Epoch:122,Training error:0.144721
# Epoch:123,Training error:0.144182
# Epoch:124,Training error:0.144049
# Epoch:125,Training error:0.144072
# Epoch:126,Training error:0.144368
# Epoch:127,Training error:0.144886
# Epoch:128,Training error:0.144239
# Epoch:129,Training error:0.144681
# Epoch:130,Training error:0.144615
# Epoch:131,Training error:0.144301
# Epoch:132,Training error:0.143527
# Epoch:133,Training error:0.144046
# Epoch:134,Training error:0.144299
# Epoch:135,Training error:0.144185
# Epoch:136,Training error:0.143598
# Epoch:137,Training error:0.143935
# Epoch:138,Training error:0.144069
# Epoch:139,Training error:0.143775
# Epoch:140,Training error:0.143896
# Epoch:141,Training error:0.143718
# Epoch:142,Training error:0.144096
# Epoch:143,Training error:0.143881
# Epoch:144,Training error:0.143854
# Epoch:145,Training error:0.143614
# Epoch:146,Training error:0.143714
# Epoch:147,Training error:0.143662
# Epoch:148,Training error:0.143901
# Epoch:149,Training error:0.143587
# Epoch:150,Training error:0.142589
# Epoch:151,Training error:0.143359
# Epoch:152,Training error:0.143276
# Epoch:153,Training error:0.143359
# Epoch:154,Training error:0.143531
# Epoch:155,Training error:0.143168
# Epoch:156,Training error:0.143391
# Epoch:157,Training error:0.143039
# Epoch:158,Training error:0.143204
# Epoch:159,Training error:0.143171
# Epoch:160,Training error:0.142902
# Epoch:161,Training error:0.143302
# Epoch:162,Training error:0.143225
# Epoch:163,Training error:0.142919
# Epoch:164,Training error:0.143156
# Epoch:165,Training error:0.143605
# Epoch:166,Training error:0.142607
# Epoch:167,Training error:0.142845
# Epoch:168,Training error:0.143240
# Epoch:169,Training error:0.142911
# Epoch:170,Training error:0.143531
# Epoch:171,Training error:0.143428
# Epoch:172,Training error:0.143695
# Epoch:173,Training error:0.143399
# Epoch:174,Training error:0.142917
# Epoch:175,Training error:0.142510
# Epoch:176,Training error:0.143378
# Epoch:177,Training error:0.142504
# Epoch:178,Training error:0.143161
# Epoch:179,Training error:0.142988
# Epoch:180,Training error:0.142783
# Epoch:181,Training error:0.143193
# Epoch:182,Training error:0.142855
# Epoch:183,Training error:0.143015
# Epoch:184,Training error:0.142789
# Epoch:185,Training error:0.142682
# Epoch:186,Training error:0.142809
# Epoch:187,Training error:0.143321
# Epoch:188,Training error:0.142415
# Epoch:189,Training error:0.143028
# Epoch:190,Training error:0.142295
# Epoch:191,Training error:0.141895
# Epoch:192,Training error:0.142466
# Epoch:193,Training error:0.142365
# Epoch:194,Training error:0.142474
# Epoch:195,Training error:0.143033
# Epoch:196,Training error:0.142639
# Epoch:197,Training error:0.142703
# Epoch:198,Training error:0.142925
# Epoch:199,Training error:0.142532
# Epoch:200,Training error:0.142354
# Epoch:201,Training error:0.142795
# Epoch:202,Training error:0.142636
# Epoch:203,Training error:0.142583
# Epoch:204,Training error:0.142727
# Epoch:205,Training error:0.142707
# Epoch:206,Training error:0.142366
# Epoch:207,Training error:0.142679
# Epoch:208,Training error:0.142476
# Epoch:209,Training error:0.142136
# Epoch:210,Training error:0.141811
# Epoch:211,Training error:0.142017
# Epoch:212,Training error:0.141778
# Epoch:213,Training error:0.142390
# Epoch:214,Training error:0.142571
# Epoch:215,Training error:0.141680
# Epoch:216,Training error:0.141601
# Epoch:217,Training error:0.141907
# Epoch:218,Training error:0.141730
# Epoch:219,Training error:0.141912
# Epoch:220,Training error:0.141924
# Epoch:221,Training error:0.142158
# Epoch:222,Training error:0.141586
# Epoch:223,Training error:0.142107
# Epoch:224,Training error:0.142105
# Epoch:225,Training error:0.141729
# Epoch:226,Training error:0.141817
# Epoch:227,Training error:0.141794
# Epoch:228,Training error:0.141971
# Epoch:229,Training error:0.141091
# Epoch:230,Training error:0.141494
# Epoch:231,Training error:0.141777
# Epoch:232,Training error:0.141995
# Epoch:233,Training error:0.141946
# Epoch:234,Training error:0.141448
# Epoch:235,Training error:0.140951
# Epoch:236,Training error:0.141481
# Epoch:237,Training error:0.141962
# Epoch:238,Training error:0.141861
# Epoch:239,Training error:0.141278
# Epoch:240,Training error:0.141399
# Epoch:241,Training error:0.141864
# Epoch:242,Training error:0.141170
# Epoch:243,Training error:0.141535
# Epoch:244,Training error:0.141420
# Epoch:245,Training error:0.141241
# Epoch:246,Training error:0.141763
# Epoch:247,Training error:0.140959
# Epoch:248,Training error:0.141579
# Epoch:249,Training error:0.141519
# Epoch:250,Training error:0.141203
# Epoch:251,Training error:0.141657
# Epoch:252,Training error:0.141388
# Epoch:253,Training error:0.141689
# Epoch:254,Training error:0.141049
# Epoch:255,Training error:0.141624
# Epoch:256,Training error:0.141793
# Epoch:257,Training error:0.141073
# Epoch:258,Training error:0.141537
# Epoch:259,Training error:0.141631
# Epoch:260,Training error:0.141342
# Epoch:261,Training error:0.141598
# Epoch:262,Training error:0.141788
# Epoch:263,Training error:0.141179
# Epoch:264,Training error:0.141274
# Epoch:265,Training error:0.141725
# Epoch:266,Training error:0.140990
# Epoch:267,Training error:0.141043
# Epoch:268,Training error:0.141919
# Epoch:269,Training error:0.141190
# Epoch:270,Training error:0.141019
# Epoch:271,Training error:0.141540
# Epoch:272,Training error:0.141358
# Epoch:273,Training error:0.141411
# Epoch:274,Training error:0.141875
# Epoch:275,Training error:0.141331
# Epoch:276,Training error:0.141279
# Epoch:277,Training error:0.141035
# Epoch:278,Training error:0.141046
# Epoch:279,Training error:0.141083
# Epoch:280,Training error:0.140800
# Epoch:281,Training error:0.141464
# Epoch:282,Training error:0.140996
# Epoch:283,Training error:0.140956
# Epoch:284,Training error:0.141290
# Epoch:285,Training error:0.141410
# Epoch:286,Training error:0.141029
# Epoch:287,Training error:0.141166
# Epoch:288,Training error:0.141283
# Epoch:289,Training error:0.141120
# Epoch:290,Training error:0.140849
# Epoch:291,Training error:0.141114
# Epoch:292,Training error:0.140990
# Epoch:293,Training error:0.141194
# Epoch:294,Training error:0.140624
# Epoch:295,Training error:0.141629
# Epoch:296,Training error:0.141361
# Epoch:297,Training error:0.141515
# Epoch:298,Training error:0.141448
# Epoch:299,Training error:0.141077
# Epoch:300,Training error:0.140634
# Epoch:301,Training error:0.141079
# Epoch:302,Training error:0.140536
# Epoch:303,Training error:0.141704
# Epoch:304,Training error:0.140669
# Epoch:305,Training error:0.140410
# Epoch:306,Training error:0.141484
# Epoch:307,Training error:0.141137
# Epoch:308,Training error:0.140885
# Epoch:309,Training error:0.140769
# Epoch:310,Training error:0.140530
# Epoch:311,Training error:0.140806
# Epoch:312,Training error:0.140984
# Epoch:313,Training error:0.141132
# Epoch:314,Training error:0.141010
# Epoch:315,Training error:0.140941
# Epoch:316,Training error:0.141119
# Epoch:317,Training error:0.140975
# Epoch:318,Training error:0.140900
# Epoch:319,Training error:0.141526
# Epoch:320,Training error:0.141061
# Epoch:321,Training error:0.140395
# Epoch:322,Training error:0.140946
# Epoch:323,Training error:0.140316
# Epoch:324,Training error:0.141189
# Epoch:325,Training error:0.141399
# Epoch:326,Training error:0.140947
# Epoch:327,Training error:0.141110
# Epoch:328,Training error:0.140590
# Epoch:329,Training error:0.141031
# Epoch:330,Training error:0.141125
# Epoch:331,Training error:0.140540
# Epoch:332,Training error:0.141029
# Epoch:333,Training error:0.141177
# Epoch:334,Training error:0.140479
# Epoch:335,Training error:0.141164
# Epoch:336,Training error:0.141462
# Epoch:337,Training error:0.140825
# Epoch:338,Training error:0.140731
# Epoch:339,Training error:0.140661
# Epoch:340,Training error:0.141007
# Epoch:341,Training error:0.141362
# Epoch:342,Training error:0.140826
# Epoch:343,Training error:0.141285
# Epoch:344,Training error:0.141279
# Epoch:345,Training error:0.141009
# Epoch:346,Training error:0.140725
# Epoch:347,Training error:0.140754
# Epoch:348,Training error:0.140955
# Epoch:349,Training error:0.141037
# Epoch:350,Training error:0.141261
# Epoch:351,Training error:0.140889
# Epoch:352,Training error:0.141240
# Epoch:353,Training error:0.141479
# Epoch:354,Training error:0.140398
# Epoch:355,Training error:0.141056
# Epoch:356,Training error:0.140585
# Epoch:357,Training error:0.140929
# Epoch:358,Training error:0.141184
# Epoch:359,Training error:0.140700
# Epoch:360,Training error:0.140737
# Epoch:361,Training error:0.140457
# Epoch:362,Training error:0.141360
# Epoch:363,Training error:0.141201
# Epoch:364,Training error:0.140561
# Epoch:365,Training error:0.140891
# Epoch:366,Training error:0.140420
# Epoch:367,Training error:0.140653
# Epoch:368,Training error:0.140671
# Epoch:369,Training error:0.140560
# Epoch:370,Training error:0.140819
# Epoch:371,Training error:0.140394
# Epoch:372,Training error:0.141195
# Epoch:373,Training error:0.141188
# Epoch:374,Training error:0.140600
# Epoch:375,Training error:0.140750
# Epoch:376,Training error:0.141044
# Epoch:377,Training error:0.140840
# Epoch:378,Training error:0.140404
# Epoch:379,Training error:0.140561
# Epoch:380,Training error:0.141024
# Epoch:381,Training error:0.140565
# Epoch:382,Training error:0.140813
# Epoch:383,Training error:0.140607
# Epoch:384,Training error:0.140301
# Epoch:385,Training error:0.140870
# Epoch:386,Training error:0.141015
# Epoch:387,Training error:0.141322
# Epoch:388,Training error:0.140645
# Epoch:389,Training error:0.140879
# Epoch:390,Training error:0.140878
# Epoch:391,Training error:0.140566
# Epoch:392,Training error:0.141105
# Epoch:393,Training error:0.140498
# Epoch:394,Training error:0.141416
# Epoch:395,Training error:0.141085
# Epoch:396,Training error:0.140743
# Epoch:397,Training error:0.140899
# Epoch:398,Training error:0.140451
# Epoch:399,Training error:0.141635
# Epoch:400,Training error:0.141326
# Epoch:401,Training error:0.141070
# Epoch:402,Training error:0.140276
# Epoch:403,Training error:0.141071
# Epoch:404,Training error:0.141530
# Epoch:405,Training error:0.140538
# Epoch:406,Training error:0.140881
# Epoch:407,Training error:0.141134
# Epoch:408,Training error:0.141350
# Epoch:409,Training error:0.141075
# Epoch:410,Training error:0.141410
# Epoch:411,Training error:0.141302
# Epoch:412,Training error:0.141000
# Epoch:413,Training error:0.140999
# Epoch:414,Training error:0.140337
# Epoch:415,Training error:0.140611
# Epoch:416,Training error:0.140836
# Epoch:417,Training error:0.140759
# Epoch:418,Training error:0.140183
# Epoch:419,Training error:0.140509
# Epoch:420,Training error:0.140622
# Epoch:421,Training error:0.140741
# Epoch:422,Training error:0.140536
# Epoch:423,Training error:0.140492
# Epoch:424,Training error:0.140915
# Epoch:425,Training error:0.141113
# Epoch:426,Training error:0.141297
# Epoch:427,Training error:0.140786
# Epoch:428,Training error:0.140701
# Epoch:429,Training error:0.140776
# Epoch:430,Training error:0.140797
# Epoch:431,Training error:0.141269
# Epoch:432,Training error:0.140890
# Epoch:433,Training error:0.140989
# Epoch:434,Training error:0.141244
# Epoch:435,Training error:0.141051
# Epoch:436,Training error:0.141119
# Epoch:437,Training error:0.140725
# Epoch:438,Training error:0.141070
# Epoch:439,Training error:0.141050
# Epoch:440,Training error:0.141158
# Epoch:441,Training error:0.140299
# Epoch:442,Training error:0.141034
# Epoch:443,Training error:0.140703
# Epoch:444,Training error:0.140969
# Epoch:445,Training error:0.140696
# Epoch:446,Training error:0.140682
# Epoch:447,Training error:0.140684
# Epoch:448,Training error:0.140941
# Epoch:449,Training error:0.140914
# Epoch:450,Training error:0.140940
# Epoch:451,Training error:0.141250
# Epoch:452,Training error:0.140651
# Epoch:453,Training error:0.141128
# Epoch:454,Training error:0.140699
# Epoch:455,Training error:0.140555
# Epoch:456,Training error:0.140919
# Epoch:457,Training error:0.140489
# Epoch:458,Training error:0.140726
# Epoch:459,Training error:0.140941
# Epoch:460,Training error:0.140730
# Epoch:461,Training error:0.140666
# Epoch:462,Training error:0.140360
# Epoch:463,Training error:0.140704
# Epoch:464,Training error:0.140690
# Epoch:465,Training error:0.140800
# Epoch:466,Training error:0.140911
# Epoch:467,Training error:0.140461
# Epoch:468,Training error:0.140717
# Epoch:469,Training error:0.140535
# Epoch:470,Training error:0.140149
# Epoch:471,Training error:0.139679
# Epoch:472,Training error:0.139797
# Epoch:473,Training error:0.140181
# Epoch:474,Training error:0.140653
# Epoch:475,Training error:0.140336
# Epoch:476,Training error:0.140406
# Epoch:477,Training error:0.140575
# Epoch:478,Training error:0.140576
# Epoch:479,Training error:0.140826
# Epoch:480,Training error:0.140260
# Epoch:481,Training error:0.140213
# Epoch:482,Training error:0.140282
# Epoch:483,Training error:0.140517
# Epoch:484,Training error:0.140706
# Epoch:485,Training error:0.140024
# Epoch:486,Training error:0.140246
# Epoch:487,Training error:0.140940
# Epoch:488,Training error:0.140503
# Epoch:489,Training error:0.140410
# Epoch:490,Training error:0.140634
# Epoch:491,Training error:0.140997
# Epoch:492,Training error:0.140383
# Epoch:493,Training error:0.140446
# Epoch:494,Training error:0.140670
# Epoch:495,Training error:0.140610
# Epoch:496,Training error:0.140651
# Epoch:497,Training error:0.141059
# Epoch:498,Training error:0.139661
# Epoch:499,Training error:0.139814
# Epoch:500,Training error:0.140901
# Epoch:501,Training error:0.139484
# Epoch:502,Training error:0.140561
# Epoch:503,Training error:0.140505
# Epoch:504,Training error:0.140335
# Epoch:505,Training error:0.140736
# Epoch:506,Training error:0.140243
# Epoch:507,Training error:0.140551
# Epoch:508,Training error:0.140435
# Epoch:509,Training error:0.140730
# Epoch:510,Training error:0.140068
# Epoch:511,Training error:0.140525
# Epoch:512,Training error:0.140100
# Epoch:513,Training error:0.140478
# Epoch:514,Training error:0.140492
# Epoch:515,Training error:0.140900
# Epoch:516,Training error:0.140081
# Epoch:517,Training error:0.140165
# Epoch:518,Training error:0.140149
# Epoch:519,Training error:0.139978
# Epoch:520,Training error:0.140090
# Epoch:521,Training error:0.140665
# Epoch:522,Training error:0.139850
# Epoch:523,Training error:0.139564
# Epoch:524,Training error:0.140942
# Epoch:525,Training error:0.140574
# Epoch:526,Training error:0.140476
# Epoch:527,Training error:0.140118
# Epoch:528,Training error:0.140651
# Epoch:529,Training error:0.140513
# Epoch:530,Training error:0.140400
# Epoch:531,Training error:0.140292
# Epoch:532,Training error:0.140809
# Epoch:533,Training error:0.140033
# Epoch:534,Training error:0.140114
# Epoch:535,Training error:0.140613
# Epoch:536,Training error:0.140493
# Epoch:537,Training error:0.140380
# Epoch:538,Training error:0.140622
# Epoch:539,Training error:0.140440
# Epoch:540,Training error:0.139898
# Epoch:541,Training error:0.139406
# Epoch:542,Training error:0.139996
# Epoch:543,Training error:0.140559
# Epoch:544,Training error:0.139974
# Epoch:545,Training error:0.140869
# Epoch:546,Training error:0.140489
# Epoch:547,Training error:0.139669
# Epoch:548,Training error:0.140038
# Epoch:549,Training error:0.141043
# Epoch:550,Training error:0.140382
# Epoch:551,Training error:0.140654
# Epoch:552,Training error:0.139992
# Epoch:553,Training error:0.139891
# Epoch:554,Training error:0.140536
# Epoch:555,Training error:0.140514
# Epoch:556,Training error:0.140260
# Epoch:557,Training error:0.140163
# Epoch:558,Training error:0.139666
# Epoch:559,Training error:0.140321
# Epoch:560,Training error:0.140240
# Epoch:561,Training error:0.140204
# Epoch:562,Training error:0.140394
# Epoch:563,Training error:0.140056
# Epoch:564,Training error:0.140516
# Epoch:565,Training error:0.140615
# Epoch:566,Training error:0.140596
# Epoch:567,Training error:0.140111
# Epoch:568,Training error:0.139471
# Epoch:569,Training error:0.140284
# Epoch:570,Training error:0.140214
# Epoch:571,Training error:0.140036
# Epoch:572,Training error:0.139447
# Epoch:573,Training error:0.140208
# Epoch:574,Training error:0.140359
# Epoch:575,Training error:0.140343
# Epoch:576,Training error:0.140460
# Epoch:577,Training error:0.140270
# Epoch:578,Training error:0.140416
# Epoch:579,Training error:0.140797
# Epoch:580,Training error:0.140303
# Epoch:581,Training error:0.139665
# Epoch:582,Training error:0.139778
# Epoch:583,Training error:0.140225
# Epoch:584,Training error:0.140114
# Epoch:585,Training error:0.140332
# Epoch:586,Training error:0.140091
# Epoch:587,Training error:0.140011
# Epoch:588,Training error:0.140238
# Epoch:589,Training error:0.140126
# Epoch:590,Training error:0.140121
# Epoch:591,Training error:0.140310
# Epoch:592,Training error:0.140411
# Epoch:593,Training error:0.139994
# Epoch:594,Training error:0.139845
# Epoch:595,Training error:0.140499
# Epoch:596,Training error:0.139859
# Epoch:597,Training error:0.140245
# Epoch:598,Training error:0.140027
# Epoch:599,Training error:0.140560
# Epoch:600,Training error:0.140511
# Epoch:601,Training error:0.140384
# Epoch:602,Training error:0.140073
# Epoch:603,Training error:0.140448
# Epoch:604,Training error:0.140104
# Epoch:605,Training error:0.140100
# Epoch:606,Training error:0.140414
# Epoch:607,Training error:0.139746
# Epoch:608,Training error:0.140462
# Epoch:609,Training error:0.139840
# Epoch:610,Training error:0.139539
# Epoch:611,Training error:0.139965
# Epoch:612,Training error:0.140259
# Epoch:613,Training error:0.139941
# Epoch:614,Training error:0.140492
# Epoch:615,Training error:0.139928
# Epoch:616,Training error:0.140307
# Epoch:617,Training error:0.140250
# Epoch:618,Training error:0.140506
# Epoch:619,Training error:0.140420
# Epoch:620,Training error:0.139744
# Epoch:621,Training error:0.140162
# Epoch:622,Training error:0.140700
# Epoch:623,Training error:0.140458
# Epoch:624,Training error:0.140171
# Epoch:625,Training error:0.140318
# Epoch:626,Training error:0.140248
# Epoch:627,Training error:0.140182
# Epoch:628,Training error:0.139965
# Epoch:629,Training error:0.140449
# Epoch:630,Training error:0.140344
# Epoch:631,Training error:0.140409
# Epoch:632,Training error:0.139942
# Epoch:633,Training error:0.140409
# Epoch:634,Training error:0.139635
# Epoch:635,Training error:0.140253
# Epoch:636,Training error:0.140133
# Epoch:637,Training error:0.140120
# Epoch:638,Training error:0.140669
# Epoch:639,Training error:0.139866
# Epoch:640,Training error:0.140376
# Epoch:641,Training error:0.140016
# Epoch:642,Training error:0.140421
# Epoch:643,Training error:0.139830
# Epoch:644,Training error:0.140369
# Epoch:645,Training error:0.140270
# Epoch:646,Training error:0.140175
# Epoch:647,Training error:0.140046
# Epoch:648,Training error:0.140507
# Epoch:649,Training error:0.139877
# Epoch:650,Training error:0.139395
# Epoch:651,Training error:0.140293
# Epoch:652,Training error:0.140079
# Epoch:653,Training error:0.139947
# Epoch:654,Training error:0.140374
# Epoch:655,Training error:0.140276
# Epoch:656,Training error:0.139841
# Epoch:657,Training error:0.140137
# Epoch:658,Training error:0.140278
# Epoch:659,Training error:0.140429
# Epoch:660,Training error:0.140220
# Epoch:661,Training error:0.140122
# Epoch:662,Training error:0.139863
# Epoch:663,Training error:0.139990
# Epoch:664,Training error:0.139691
# Epoch:665,Training error:0.140101
# Epoch:666,Training error:0.140450
# Epoch:667,Training error:0.140090
# Epoch:668,Training error:0.139760
# Epoch:669,Training error:0.140124
# Epoch:670,Training error:0.140070
# Epoch:671,Training error:0.140006
# Epoch:672,Training error:0.139781
# Epoch:673,Training error:0.139954
# Epoch:674,Training error:0.140649
# Epoch:675,Training error:0.139935
# Epoch:676,Training error:0.139726
# Epoch:677,Training error:0.139990
# Epoch:678,Training error:0.139932
# Epoch:679,Training error:0.140274
# Epoch:680,Training error:0.140132
# Epoch:681,Training error:0.140576
# Epoch:682,Training error:0.139829
# Epoch:683,Training error:0.140460
# Epoch:684,Training error:0.140421
# Epoch:685,Training error:0.139831
# Epoch:686,Training error:0.139723
# Epoch:687,Training error:0.139900
# Epoch:688,Training error:0.139882
# Epoch:689,Training error:0.139752
# Epoch:690,Training error:0.139762
# Epoch:691,Training error:0.140540
# Epoch:692,Training error:0.140321
# Epoch:693,Training error:0.140450
# Epoch:694,Training error:0.139890
# Epoch:695,Training error:0.139733
# Epoch:696,Training error:0.140285
# Epoch:697,Training error:0.139509
# Epoch:698,Training error:0.139993
# Epoch:699,Training error:0.139975
# Epoch:700,Training error:0.140035
# Epoch:701,Training error:0.139855
# Epoch:702,Training error:0.139591
# Epoch:703,Training error:0.139880
# Epoch:704,Training error:0.139786
# Epoch:705,Training error:0.139925
# Epoch:706,Training error:0.139970
# Epoch:707,Training error:0.140469
# Epoch:708,Training error:0.139595
# Epoch:709,Training error:0.139429
# Epoch:710,Training error:0.139844
# Epoch:711,Training error:0.139749
# Epoch:712,Training error:0.139690
# Epoch:713,Training error:0.139681
# Epoch:714,Training error:0.140574
# Epoch:715,Training error:0.140300
# Epoch:716,Training error:0.140144
# Epoch:717,Training error:0.140625
# Epoch:718,Training error:0.140037
# Epoch:719,Training error:0.139819
# Epoch:720,Training error:0.140206
# Epoch:721,Training error:0.140673
# Epoch:722,Training error:0.140364
# Epoch:723,Training error:0.139569
# Epoch:724,Training error:0.139999
# Epoch:725,Training error:0.140215
# Epoch:726,Training error:0.139689
# Epoch:727,Training error:0.140392
# Epoch:728,Training error:0.139660
# Epoch:729,Training error:0.139918
# Epoch:730,Training error:0.139997
# Epoch:731,Training error:0.139865
# Epoch:732,Training error:0.140173
# Epoch:733,Training error:0.139584
# Epoch:734,Training error:0.140544
# Epoch:735,Training error:0.139900
# Epoch:736,Training error:0.139659
# Epoch:737,Training error:0.140238
# Epoch:738,Training error:0.140195
# Epoch:739,Training error:0.140518
# Epoch:740,Training error:0.140213
# Epoch:741,Training error:0.140236
# Epoch:742,Training error:0.140269
# Epoch:743,Training error:0.140473
# Epoch:744,Training error:0.140227
# Epoch:745,Training error:0.140278
# Epoch:746,Training error:0.140055
# Epoch:747,Training error:0.140166
# Epoch:748,Training error:0.139897
# Epoch:749,Training error:0.140202
# Epoch:750,Training error:0.140006
# Epoch:751,Training error:0.139704
# Epoch:752,Training error:0.140254
# Epoch:753,Training error:0.139538
# Epoch:754,Training error:0.140726
# Epoch:755,Training error:0.140199
# Epoch:756,Training error:0.140203
# Epoch:757,Training error:0.140306
# Epoch:758,Training error:0.140279
# Epoch:759,Training error:0.139733
# Epoch:760,Training error:0.140019
# Epoch:761,Training error:0.140011
# Epoch:762,Training error:0.140202
# Epoch:763,Training error:0.140326
# Epoch:764,Training error:0.139872
# Epoch:765,Training error:0.140431
# Epoch:766,Training error:0.140195
# Epoch:767,Training error:0.140161
# Epoch:768,Training error:0.139920
# Epoch:769,Training error:0.140510
# Epoch:770,Training error:0.139895
# Epoch:771,Training error:0.139906
# Epoch:772,Training error:0.140520
# Epoch:773,Training error:0.139910
# Epoch:774,Training error:0.139951
# Epoch:775,Training error:0.139742
# Epoch:776,Training error:0.139611
# Epoch:777,Training error:0.139871
# Epoch:778,Training error:0.140156
# Epoch:779,Training error:0.140072
# Epoch:780,Training error:0.140156
# Epoch:781,Training error:0.139968
# Epoch:782,Training error:0.139947
# Epoch:783,Training error:0.139747
# Epoch:784,Training error:0.139736
# Epoch:785,Training error:0.140098
# Epoch:786,Training error:0.140161
# Epoch:787,Training error:0.140939
# Epoch:788,Training error:0.140395
# Epoch:789,Training error:0.140568
# Epoch:790,Training error:0.140598
# Epoch:791,Training error:0.140096
# Epoch:792,Training error:0.141084
# Epoch:793,Training error:0.140452
# Epoch:794,Training error:0.139540
# Epoch:795,Training error:0.140935
# Epoch:796,Training error:0.140465
# Epoch:797,Training error:0.140372
# Epoch:798,Training error:0.140534
# Epoch:799,Training error:0.140025
# Epoch:800,Training error:0.140018
# Epoch:801,Training error:0.140350
# Epoch:802,Training error:0.140924
# Epoch:803,Training error:0.139731
# Epoch:804,Training error:0.140839
# Epoch:805,Training error:0.140276
# Epoch:806,Training error:0.140491
# Epoch:807,Training error:0.139759
# Epoch:808,Training error:0.140653
# Epoch:809,Training error:0.139576
# Epoch:810,Training error:0.140446
# Epoch:811,Training error:0.140230
# Epoch:812,Training error:0.140497
# Epoch:813,Training error:0.139584
# Epoch:814,Training error:0.140607
# Epoch:815,Training error:0.140896
# Epoch:816,Training error:0.140756
# Epoch:817,Training error:0.139916
# Epoch:818,Training error:0.139523
# Epoch:819,Training error:0.140435
# Epoch:820,Training error:0.140585
# Epoch:821,Training error:0.140254
# Epoch:822,Training error:0.140096
# Epoch:823,Training error:0.140111
# Epoch:824,Training error:0.140551
# Epoch:825,Training error:0.139870
# Epoch:826,Training error:0.140149
# Epoch:827,Training error:0.140030
# Epoch:828,Training error:0.140405
# Epoch:829,Training error:0.140566
# Epoch:830,Training error:0.141036
# Epoch:831,Training error:0.140089
# Epoch:832,Training error:0.139784
# Epoch:833,Training error:0.140213
# Epoch:834,Training error:0.139422
# Epoch:835,Training error:0.140050
# Epoch:836,Training error:0.140264
# Epoch:837,Training error:0.139972
# Epoch:838,Training error:0.140300
# Epoch:839,Training error:0.140254
# Epoch:840,Training error:0.140923
# Epoch:841,Training error:0.140441
# Epoch:842,Training error:0.140192
# Epoch:843,Training error:0.140213
# Epoch:844,Training error:0.139977
# Epoch:845,Training error:0.140374
# Epoch:846,Training error:0.139824
# Epoch:847,Training error:0.140060
# Epoch:848,Training error:0.140406
# Epoch:849,Training error:0.140503
# Epoch:850,Training error:0.140681
# Epoch:851,Training error:0.139768
# Epoch:852,Training error:0.140041
# Epoch:853,Training error:0.139736
# Epoch:854,Training error:0.140355
# Epoch:855,Training error:0.140765
# Epoch:856,Training error:0.139947
# Epoch:857,Training error:0.140260
# Epoch:858,Training error:0.139948
# Epoch:859,Training error:0.140377
# Epoch:860,Training error:0.140240
# Epoch:861,Training error:0.140010
# Epoch:862,Training error:0.140686
# Epoch:863,Training error:0.139808
# Epoch:864,Training error:0.139982
# Epoch:865,Training error:0.140968
# Epoch:866,Training error:0.140541
# Epoch:867,Training error:0.140816
# Epoch:868,Training error:0.140229
# Epoch:869,Training error:0.140106
# Epoch:870,Training error:0.140230
# Epoch:871,Training error:0.139728
# Epoch:872,Training error:0.140791
# Epoch:873,Training error:0.141102
# Epoch:874,Training error:0.140589
# Epoch:875,Training error:0.140171
# Epoch:876,Training error:0.139767
# Epoch:877,Training error:0.140277
# Epoch:878,Training error:0.140426
# Epoch:879,Training error:0.140284
# Epoch:880,Training error:0.140144
# Epoch:881,Training error:0.140185
# Epoch:882,Training error:0.140950
# Epoch:883,Training error:0.140292
# Epoch:884,Training error:0.140582
# Epoch:885,Training error:0.140360
# Epoch:886,Training error:0.140264
# Epoch:887,Training error:0.140823
# Epoch:888,Training error:0.140600
# Epoch:889,Training error:0.140441
# Epoch:890,Training error:0.140325
# Epoch:891,Training error:0.140407
# Epoch:892,Training error:0.140209
# Epoch:893,Training error:0.139921
# Epoch:894,Training error:0.140222
# Epoch:895,Training error:0.140746
# Epoch:896,Training error:0.139984
# Epoch:897,Training error:0.140076
# Epoch:898,Training error:0.139759
# Epoch:899,Training error:0.140221
# Epoch:900,Training error:0.140117
# Epoch:901,Training error:0.140765
# Epoch:902,Training error:0.140416
# Epoch:903,Training error:0.140402
# Epoch:904,Training error:0.140475
# Epoch:905,Training error:0.140748
# Epoch:906,Training error:0.140580
# Epoch:907,Training error:0.140082
# Epoch:908,Training error:0.139934
# Epoch:909,Training error:0.140291
# Epoch:910,Training error:0.140165
# Epoch:911,Training error:0.140385
# Epoch:912,Training error:0.140102
# Epoch:913,Training error:0.139904
# Epoch:914,Training error:0.140444
# Epoch:915,Training error:0.140282
# Epoch:916,Training error:0.139394
# Epoch:917,Training error:0.140091
# Epoch:918,Training error:0.139971
# Epoch:919,Training error:0.140128
# Epoch:920,Training error:0.140309
# Epoch:921,Training error:0.140409
# Epoch:922,Training error:0.140153
# Epoch:923,Training error:0.140705
# Epoch:924,Training error:0.140379
# Epoch:925,Training error:0.140120
# Epoch:926,Training error:0.140353
# Epoch:927,Training error:0.140839
# Epoch:928,Training error:0.140646
# Epoch:929,Training error:0.139864
# Epoch:930,Training error:0.140308
# Epoch:931,Training error:0.140359
# Epoch:932,Training error:0.140158
# Epoch:933,Training error:0.139825
# Epoch:934,Training error:0.140116
# Epoch:935,Training error:0.140090
# Epoch:936,Training error:0.140344
# Epoch:937,Training error:0.140182
# Epoch:938,Training error:0.139836
# Epoch:939,Training error:0.140079
# Epoch:940,Training error:0.139561
# Epoch:941,Training error:0.140023
# Epoch:942,Training error:0.140080
# Epoch:943,Training error:0.140229
# Epoch:944,Training error:0.140060
# Epoch:945,Training error:0.140484
# Epoch:946,Training error:0.139728
# Epoch:947,Training error:0.140200
# Epoch:948,Training error:0.140483
# Epoch:949,Training error:0.140246
# Epoch:950,Training error:0.140136
# Epoch:951,Training error:0.140601
# Epoch:952,Training error:0.139900
# Epoch:953,Training error:0.140218
# Epoch:954,Training error:0.140052
# Epoch:955,Training error:0.140441
# Epoch:956,Training error:0.140333
# Epoch:957,Training error:0.140425
# Epoch:958,Training error:0.140027
# Epoch:959,Training error:0.139995
# Epoch:960,Training error:0.140504
# Epoch:961,Training error:0.140441
# Epoch:962,Training error:0.140211
# Epoch:963,Training error:0.140063
# Epoch:964,Training error:0.140949
# Epoch:965,Training error:0.140899
# Epoch:966,Training error:0.140261
# Epoch:967,Training error:0.139759
# Epoch:968,Training error:0.141052
# Epoch:969,Training error:0.140471
# Epoch:970,Training error:0.140056
# Epoch:971,Training error:0.140199
# Epoch:972,Training error:0.140250
# Epoch:973,Training error:0.139883
# Epoch:974,Training error:0.140401
# Epoch:975,Training error:0.140805
# Epoch:976,Training error:0.141314
# Epoch:977,Training error:0.140060
# Epoch:978,Training error:0.140166
# Epoch:979,Training error:0.140884
# Epoch:980,Training error:0.140490
# Epoch:981,Training error:0.140785
# Epoch:982,Training error:0.140474
# Epoch:983,Training error:0.140146
# Epoch:984,Training error:0.140091
# Epoch:985,Training error:0.140620
# Epoch:986,Training error:0.140454
# Epoch:987,Training error:0.140617
# Epoch:988,Training error:0.140436
# Epoch:989,Training error:0.140391
# Epoch:990,Training error:0.140028
# Epoch:991,Training error:0.140402
# Epoch:992,Training error:0.140431
# Epoch:993,Training error:0.140382
# Epoch:994,Training error:0.139923
# Epoch:995,Training error:0.140156
# Epoch:996,Training error:0.140385
# Epoch:997,Training error:0.140230
# Epoch:998,Training error:0.140880
# Epoch:999,Training error:0.140512

# %%
plt.plot(np.arange(1000), rbm.error_history)
plt.xlabel("Epochs")
plt.ylabel("error")
# Out:
# Text(0, 0.5, 'error')

# %%
recons_array = rbm.reconstruction(1, new_data_test.T)

# %%
recons_array.shape
# Out:
# (100, 1000)

# %%
def energy_ising_1d(configuration,J,h):
    num_spins = len(configuration)
    energy = 0.0
    for i in range(num_spins):
        spini = configuration[i]
        #set the value of spin i+1, make sure to test if i+1<num_spins, and otherwise account for periodic boundaries
        #you can do this with an if statement if you have to
        ip1 = (i+1)%num_spins
        spinip1 = configuration[ip1]
        
        energy = energy - J * (spini * spinip1) - h*spini
        
    return energy

def energy_batch(configs,J,h):
    energies = np.array([energy_ising_1d(config,J,h) for config in configs])
    
    return energies

def avg_energy(configs,J,h):
    return np.mean(energy_batch(configs,J,h))

# %%
recons_energy =  energy_batch(recons_array.T,J=1,h=0)

# %%
recons_energy.shape
# Out:
# (1000,)

# %%
data_energy = energy_batch(new_data_test,J=1,h=0)

# %%
data_energy.shape
# Out:
# (1000,)

# %%
plt.scatter(data_energy, recons_energy)
plt.ylabel("$recons_energy$")
plt.xlabel("data_energy")
# Out:
# Text(0.5, 0, 'data_energy')

# %%
plt.plot(data_energy)
plt.plot(recons_energy)

# %%
mean_data = np.mean(data_energy)

# %%
mean_data
# Out:
# -76.356

# %%
mean_recons = np.mean(recons_energy)

# %%
mean_recons
# Out:
# -60.584

# %%
std_data = np.std(data_energy)

# %%
std_data
# Out:
# 6.159912255868585

# %%
std_recons = np.std(recons_energy)

# %%
std_recons
# Out:
# 7.986488339689729
