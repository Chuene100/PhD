# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# In this notebook, we show how the Restricted Boltzmann Machine (RBM) update its parameters by minimizing the Log-likelihood and we minimise the cross-entropy as a loss function.
#
# The first function in this notebook shows the minimizaion of the Log-likelihood. The second function shows the minimization of the cross-entropy.
#
# TensorFlow has been employed for further minimizations.

# %% [markdown]
# # Log-likelihood

# %%
class RBM(object):
    def __init__(self, vis_unit, hidd_unit,temps=tf.constant(1)):
        self.vis_unit = vis_unit
        self.hidd_unit = hidd_unit
        self.temps=temps
        
        #Initialise the parameters
        self.W = tf.random.uniform([self.vis_unit, self.hidd_unit],0,1)
           
################################################ Updating Parameters ##########################################        
    
    
    #Derivative of the log probability
    def VH(self, vis, hid):
        shvd = tf.tensordot(vis, tf.transpose(hid), axes=1)
        return shvd
        
   
    # Upgrade the gradient
    def W_Update(self, vis):
        #Positive phase
        hid=self.forward_pass(vis)
        der_W1 =self.VH(vis ,hid) 
    
        #Negative phase
        vis_r = self.reconstruction(self.CD_k, vis)
        hid_r= self.forward_pass(vis_r)
        der_W2 = self.VH(vis_r, hid_r)
        der_W=-der_W2+der_W1
        
        #Updating the parameters
        self.W = self.W + self.learning_rate * der_W/vis.shape[1]
        

########################################### Reconstruction ####################################################       
        
     #Calculate the hidden states
    def forward_pass(self, vis):
        X = tf.tensordot(tf.transpose(self.W), vis, axes=1)
        p_h = 1.0/(1.0 + tf.exp(-2*X))
        hid = 2*tf.cast(p_h>tf.random.uniform([self.hidd_unit,vis.shape[1]],0,1),tf.float32)-1
        #hid = tf.nn.sigmoid(X)
        return  hid          
            
    # Reconstruct the visible states
    def backward_pass(self, hid):
        X = tf.tensordot(self.W, hid, axes=1)
        p_v = 1.0/(1.0+tf.exp(-2*X))
        v_r = 2*tf.cast(p_v>tf.random.uniform([self.vis_unit,hid.shape[1]],0,1),tf.float32)-1
        #v_r = tf.nn.sigmoid(X)
        return v_r
            
    # Perform Gibbs Sampling
    def reconstruction(self, steps, vis):
        vis_r=vis
        for i in tf.range(steps):
            hid = self.forward_pass(vis_r)
            vis_r = self.backward_pass(hid)
        return vis_r
    
############################################# Training ########################################################

    #Training Model
    def learn(self, training_data, learning_rate=0.01, epochs=10, batch_size=1, CD_k=1):
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.batch_size = batch_size
        self.CD_k = CD_k
        
        num_batches = int(training_data.shape[0]/self.batch_size)
        self.error_history = tf.zeros(self.epochs).numpy()
        
        
        for k in range(self.epochs):
            error = 0
            for b in range(0, num_batches):
                batch = training_data[int(b*self.batch_size):int((b+1)*self.batch_size)]
                vis=tf.cast(tf.transpose(batch),tf.float32)
                self.W_Update(vis)
                samples = self.reconstruction(1, vis)
                error+=0.25*tf.reduce_sum(tf.square(vis-samples))/tf.cast(tf.reduce_prod(vis.shape),tf.float32)
            error = error/num_batches
            self.error_history[k] = error
            print('Epoch:%d,Training error:%f'%(k, error))

# %%
training_data = np.loadtxt('/Users/chuene/Documents/PhD/Pallab/filename.txt')
data = training_data.reshape(10000,100)
new_data = data[1000:,:]
new_data_train = new_data[:8000]

# %%
rbm1 = RBM(vis_unit = 100, hidd_unit=20)
model = rbm1.learn(training_data=new_data_train, learning_rate=0.01,epochs=100, CD_k=1, batch_size=50)

plt.plot(np.arange(100), rbm1.error_history)
plt.xlabel("Epochs")
plt.ylabel("Error")
# Out:
# Epoch:0,Training error:0.328933
# Epoch:1,Training error:0.264142
# Epoch:2,Training error:0.240736
# Epoch:3,Training error:0.229330
# Epoch:4,Training error:0.222299
# Epoch:5,Training error:0.216145
# Epoch:6,Training error:0.212100
# Epoch:7,Training error:0.210071
# Epoch:8,Training error:0.206781
# Epoch:9,Training error:0.204619
# Epoch:10,Training error:0.201874
# Epoch:11,Training error:0.200627
# Epoch:12,Training error:0.199367
# Epoch:13,Training error:0.197070
# Epoch:14,Training error:0.196403
# Epoch:15,Training error:0.195400
# Epoch:16,Training error:0.194366
# Epoch:17,Training error:0.194068
# Epoch:18,Training error:0.193383
# Epoch:19,Training error:0.192626
# Epoch:20,Training error:0.192574
# Epoch:21,Training error:0.191555
# Epoch:22,Training error:0.191271
# Epoch:23,Training error:0.190747
# Epoch:24,Training error:0.190577
# Epoch:25,Training error:0.189260
# Epoch:26,Training error:0.188930
# Epoch:27,Training error:0.189490
# Epoch:28,Training error:0.189084
# Epoch:29,Training error:0.188212
# Epoch:30,Training error:0.188639
# Epoch:31,Training error:0.187841
# Epoch:32,Training error:0.187416
# Epoch:33,Training error:0.188997
# Epoch:34,Training error:0.187415
# Epoch:35,Training error:0.187214
# Epoch:36,Training error:0.187245
# Epoch:37,Training error:0.187085
# Epoch:38,Training error:0.187054
# Epoch:39,Training error:0.187204
# Epoch:40,Training error:0.187523
# Epoch:41,Training error:0.187100
# Epoch:42,Training error:0.187029
# Epoch:43,Training error:0.186475
# Epoch:44,Training error:0.187435
# Epoch:45,Training error:0.186687
# Epoch:46,Training error:0.186746
# Epoch:47,Training error:0.186641
# Epoch:48,Training error:0.186485
# Epoch:49,Training error:0.186552
# Epoch:50,Training error:0.186895
# Epoch:51,Training error:0.186925
# Epoch:52,Training error:0.186385
# Epoch:53,Training error:0.186389
# Epoch:54,Training error:0.186825
# Epoch:55,Training error:0.186045
# Epoch:56,Training error:0.186446
# Epoch:57,Training error:0.186844
# Epoch:58,Training error:0.186549
# Epoch:59,Training error:0.186951
# Epoch:60,Training error:0.186186
# Epoch:61,Training error:0.185936
# Epoch:62,Training error:0.186442
# Epoch:63,Training error:0.186450
# Epoch:64,Training error:0.186833
# Epoch:65,Training error:0.186772
# Epoch:66,Training error:0.186370
# Epoch:67,Training error:0.186559
# Epoch:68,Training error:0.185911
# Epoch:69,Training error:0.185351
# Epoch:70,Training error:0.185719
# Epoch:71,Training error:0.185483
# Epoch:72,Training error:0.185512
# Epoch:73,Training error:0.186278
# Epoch:74,Training error:0.185794
# Epoch:75,Training error:0.186217
# Epoch:76,Training error:0.185939
# Epoch:77,Training error:0.186314
# Epoch:78,Training error:0.185659
# Epoch:79,Training error:0.186053
# Epoch:80,Training error:0.185360
# Epoch:81,Training error:0.185639
# Epoch:82,Training error:0.185102
# Epoch:83,Training error:0.185814
# Epoch:84,Training error:0.185791
# Epoch:85,Training error:0.185305
# Epoch:86,Training error:0.185929
# Epoch:87,Training error:0.186276
# Epoch:88,Training error:0.185475
# Epoch:89,Training error:0.185287
# Epoch:90,Training error:0.185585
# Epoch:91,Training error:0.185266
# Epoch:92,Training error:0.185906
# Epoch:93,Training error:0.185855
# Epoch:94,Training error:0.186324
# Epoch:95,Training error:0.185777
# Epoch:96,Training error:0.185924
# Epoch:97,Training error:0.185039
# Epoch:98,Training error:0.185029
# Epoch:99,Training error:0.185679
# Text(0, 0.5, 'Error')

# %% [markdown]
# # Cross-Entropy

# %%
class RBM(object):
    def __init__(self, vis_unit, hidd_unit,temps=tf.constant(1)):
        self.vis_unit = vis_unit
        self.hidd_unit = hidd_unit
        self.temps=temps
        
        #Initialise the parameters
        self.W = tf.random.uniform([self.vis_unit, self.hidd_unit],0,1)
        
################################################ Updating Parameters ##########################################        
    
    
    #Derivative of the log probability
    def VH(self, vis,hid):
        shvd = tf.tensordot(vis,tf.transpose(hid),axes=1)
        return shvd
        
   
    # Upgrade the gradient
    def W_Update(self, vis):
        #Positive phase
        hid=self.forward_pass(vis)
        der_W1 =self.VH(vis,hid) 
    
        #Negative phase
        vis_r  = self.reconstruction(self.CD_k, vis)
        hid_r  = self.forward_pass(vis_r)
        der_W2 = self.VH(vis_r,hid_r)
        der_W  = -self.vis_unit*der_W2 + self.vis_unit*der_W1
        
        #Updating the parameters
        self.W = self.W + self.learning_rate * der_W/vis.shape[1]
        

########################################### Reconstruction ####################################################       
        
     #Calculate the hidden states
    def forward_pass(self, vis):
        X = tf.tensordot(tf.transpose(self.W), vis, axes=1)
        p_h = 1.0/(1.0+tf.exp(-X))
        hid = 2*tf.cast(p_h>tf.random.uniform([self.hidd_unit, vis.shape[1]],0,1),tf.float32)-1
        #hid = tf.nn.sigmoid(X)
        return  hid          
            
    # Reconstruct the visible states
    def backward_pass(self, hid):
        X = tf.tensordot(self.W, hid, axes=1)
        p_v = 1.0/(1.0+tf.exp(-X))
        v_r = 2*tf.cast(p_v>tf.random.uniform([self.vis_unit,hid.shape[1]],0,1),tf.float32)-1
        #v_r = tf.nn.sigmoid(X)
        return v_r
            
    # Perform Gibbs Sampling
    def reconstruction(self, steps, vis):
        vis_r=vis
        for i in tf.range(steps):
            hid = self.forward_pass(vis_r)
            vis_r = self.backward_pass(hid)
        return vis_r
    
############################################# Training ########################################################

    #Training Model
    def learn(self, training_data, learning_rate=0.01, epochs=10, batch_size=1, CD_k=1):
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.batch_size = batch_size
        self.CD_k = CD_k
        
        num_batches = int(training_data.shape[0]/self.batch_size)
        self.error_history = tf.zeros(self.epochs).numpy()
        
        for k in range(self.epochs):
            error = 0
            for b in range(0, num_batches):
                batch = training_data[int(b*self.batch_size):int((b+1)*self.batch_size)]
                vis=tf.transpose(tf.cast(batch, tf.float32))
                self.W_Update(vis)
                samples = self.reconstruction(1, vis)
                error+=0.25*tf.reduce_sum(tf.square(vis-samples))/tf.cast(tf.reduce_prod(vis.shape),tf.float32)
            error = error/num_batches
            self.error_history[k] = error
            print('Epoch:%d,Training error:%f'%(k, error))

# %%
training_data = np.loadtxt('/Users/chuene/Documents/PhD/Pallab/filename.txt')
data = training_data.reshape(10000,100)
new_data = data[1000:,:]
new_data_train = new_data[:8000]

# %%
rbm2 = RBM(vis_unit = 100, hidd_unit=50)
model = rbm2.learn(training_data=new_data_train, learning_rate=0.01,epochs=100, CD_k=1, batch_size=50)

plt.plot(np.arange(100), rbm2.error_history)
plt.xlabel("Epochs")
plt.ylabel("error")
# Out:
# Epoch:0,Training error:0.115468
# Epoch:1,Training error:0.081415
# Epoch:2,Training error:0.076349
# Epoch:3,Training error:0.075664
# Epoch:4,Training error:0.074675
# Epoch:5,Training error:0.074631
# Epoch:6,Training error:0.074241
# Epoch:7,Training error:0.076350
# Epoch:8,Training error:0.074443
# Epoch:9,Training error:0.073075
# Epoch:10,Training error:0.073954
# Epoch:11,Training error:0.075500
# Epoch:12,Training error:0.073636
# Epoch:13,Training error:0.073670
# Epoch:14,Training error:0.072445
# Epoch:15,Training error:0.073522
# Epoch:16,Training error:0.073277
# Epoch:17,Training error:0.075782
# Epoch:18,Training error:0.075360
# Epoch:19,Training error:0.074486
# Epoch:20,Training error:0.074769
# Epoch:21,Training error:0.076766
# Epoch:22,Training error:0.075039
# Epoch:23,Training error:0.073594
# Epoch:24,Training error:0.075679
# Epoch:25,Training error:0.072819
# Epoch:26,Training error:0.074131
# Epoch:27,Training error:0.074321
# Epoch:28,Training error:0.073356
# Epoch:29,Training error:0.075449
# Epoch:30,Training error:0.073935
# Epoch:31,Training error:0.075180
# Epoch:32,Training error:0.073873
# Epoch:33,Training error:0.073497
# Epoch:34,Training error:0.075126
# Epoch:35,Training error:0.074392
# Epoch:36,Training error:0.072879
# Epoch:37,Training error:0.074183
# Epoch:38,Training error:0.074899
# Epoch:39,Training error:0.074947
# Epoch:40,Training error:0.074894
# Epoch:41,Training error:0.074147
# Epoch:42,Training error:0.072472
# Epoch:43,Training error:0.073383
# Epoch:44,Training error:0.074317
# Epoch:45,Training error:0.073151
# Epoch:46,Training error:0.074154
# Epoch:47,Training error:0.074225
# Epoch:48,Training error:0.073640
# Epoch:49,Training error:0.075878
# Epoch:50,Training error:0.074371
# Epoch:51,Training error:0.074074
# Epoch:52,Training error:0.074715
# Epoch:53,Training error:0.073090
# Epoch:54,Training error:0.072159
# Epoch:55,Training error:0.073894
# Epoch:56,Training error:0.073101
# Epoch:57,Training error:0.074453
# Epoch:58,Training error:0.073852
# Epoch:59,Training error:0.074469
# Epoch:60,Training error:0.074311
# Epoch:61,Training error:0.074304
# Epoch:62,Training error:0.075493
# Epoch:63,Training error:0.075996
# Epoch:64,Training error:0.074488
# Epoch:65,Training error:0.071972
# Epoch:66,Training error:0.073701
# Epoch:67,Training error:0.073415
# Epoch:68,Training error:0.073748
# Epoch:69,Training error:0.074939
# Epoch:70,Training error:0.074333
# Epoch:71,Training error:0.074419
# Epoch:72,Training error:0.073950
# Epoch:73,Training error:0.074484
# Epoch:74,Training error:0.073790
# Epoch:75,Training error:0.073634
# Epoch:76,Training error:0.072636
# Epoch:77,Training error:0.075741
# Epoch:78,Training error:0.074139
# Epoch:79,Training error:0.073029
# Epoch:80,Training error:0.074408
# Epoch:81,Training error:0.074827
# Epoch:82,Training error:0.075171
# Epoch:83,Training error:0.074464
# Epoch:84,Training error:0.074123
# Epoch:85,Training error:0.074205
# Epoch:86,Training error:0.074872
# Epoch:87,Training error:0.074161
# Epoch:88,Training error:0.074553
# Epoch:89,Training error:0.074464
# Epoch:90,Training error:0.074845
# Epoch:91,Training error:0.074317
# Epoch:92,Training error:0.074781
# Epoch:93,Training error:0.073528
# Epoch:94,Training error:0.072879
# Epoch:95,Training error:0.074006
# Epoch:96,Training error:0.074107
# Epoch:97,Training error:0.075461
# Epoch:98,Training error:0.075816
# Epoch:99,Training error:0.075019
# Text(0, 0.5, 'error')
